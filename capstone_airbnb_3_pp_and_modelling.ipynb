# %% [markdown]
# # Pre-processing and Modelling

# %%
# import all libraries here

import pandas as pd

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import ElasticNet, ElasticNetCV, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, BaggingRegressor
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.compose import ColumnTransformer

from scipy import stats

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from yellowbrick.regressor import ResidualsPlot

from sklearn.tree import export_graphviz
import graphviz

import joblib

# %%
# loading the visualisation dataframe

df_vis = joblib.load('data/jlib_files/dataframes/complete_df_2_modelling.jlib')

# %%
# loading the adapted dataframe for modelling

df = joblib.load('data/jlib_files/dataframes/modelling_df_2_modelling.jlib')

# %% [markdown]
# ## Pre-processing
#
# For the time being, I'm not going to be including any NLP in my model, so I'll drop all of the text variables from my dataframe. I'll then separate the dataset in to predictor (X) and target (y) datasets.

# %%
X = df.copy()

y = X.pop('price')

X.drop(['name', 'description', 'neighborhood_overview', 'host_about'], axis=1, inplace=True)

# %% [markdown]
# ## Train and Test Splits
#
# The datasets are then going to be separated by 80:20 in to train and test splits. This allows to fit the model on the training set and then use the test set to gauge how well the model performs on unseen data.
#
# The dataset will be shuffled prior to the split in case the dataset has been ordered by a unique identifier or date.

# %%
# setting up train and test split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1, shuffle=True)

# %% [markdown]
# ## Setting up ColumnTransformer
#
# I'm going to be transforming the dataset in the following ways:
#
# - One-hot encoding the categorical variables, such as neighbourhood and room_type, so they are binary columns for each different value.
# - Plugging the OneHotEncoder through ColumnTransformer allows me to only make this change to the categorical variables I've listed. The encoder will 'pass through' all other columns.
# - Standardising all predictor variables using scikit-learn's StandardScaler, centring the mean to 0 and scaling to unit variance. This is a necessity for linear regression models with regularisation, which are the first models I'm going to be applying to the dataset.

# %%
# setting up the pipeline to transform the data

categorical_variables = ['host_response_time', 'host_response_rate', 'host_acceptance_rate',
                         'neighbourhood', 'room_type', 'property_type_basic']

# instantiating my transformers

one_hot = OneHotEncoder(sparse=False, drop='first')
scaler = StandardScaler(with_mean=True, with_std=True)

col_trans = ColumnTransformer(
[('dummy', one_hot, categorical_variables)],
remainder='passthrough',
sparse_threshold=0)

# %% [markdown]
# ## Log transformation of the target variable
#
# Before I start modelling, I'm going to do a final transformation to the target variable. As the histogram below shows, the distribution of property prices is heavily skewed to the right. This might affect the performance of my model as linear regression assumes that the residuals are normally distributed. To resolve this, I'm going to perform a log transformation of the target variable so it has more of a normal distribution.

# %%
fig,ax = plt.subplots(2,1,figsize=(18,12))

ax[0].hist(x=y, bins=30)
ax[1].hist(x=np.log(y), bins=30)

ax[0].set_title('Distribution of Price Variable', fontsize=18)
ax[1].set_title('Distribution of Log-Transformed Price Variable', fontsize=18)

ax[0].set_xlabel('Price', fontsize=14)
ax[1].set_xlabel('Log of Price', fontsize=14)

ax[0].margins(x=0)
ax[1].margins(x=0)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Linear regression with regularisation
#
#
# The first models I'm going to try are linear regression models with regularisation (Ridge, Lasso and Elastic Net). As linear regression is much less computationally expensive than ensemble models, which I'll be trying later on, these are always a good place to start when using regression to solve a problem.
#
# Given that my dataset has a lot of variables, some of which have correlation between one another, it wouldn't make sense to use a linear regression model without regularisation.
#
# For each model, I'm going to instantiate them in their EstimatorCV formats. This will allow my to plug in a range of different hyper-parameter values to search for the model with the most optimal performance (i.e. the highest mean of the cross-validated r2 scores). Each cross-validation will be conducted over 5 folds.
#
# Finally, I'll print out the optimal hyper-parameters for each model along with the training, test and mean cross-validation scores.

# %%
# setting up a dataframe to score the scores of my models

r2_scores_df = pd.DataFrame({'Training_Score': [],'Test_Score': [],'CV_Mean_Score': []},)

# %%
# instantiating the log-transformed target variables

y_train_log = np.log(y_train)
y_test_log = np.log(y_test)

# %% [markdown]
# ### Ridge

# %%
model = RidgeCV(np.logspace(-5, 5, 100),cv=5)

pipe = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('model', model)])

pipe.fit(X_train,y_train_log)

best_alpha = model.alpha_
training_score = pipe.score(X_train, y_train_log)
cv_mean_score = model.best_score_
test_score = pipe.score(X_test, y_test_log)


model_r = Ridge(alpha=best_alpha)

pipe_r = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('model', model_r)])

pipe_r.fit(X_train, y_train_log)

cv_scores = cross_val_score(pipe_r, X_train, y_train_log, cv=5)

# get the best alpha
print('Best alpha:', best_alpha)
# evaluate on the training set
print('Training score:', training_score)
# cross-validated scores
print('CV Scores:', cv_scores)
# mean cross-validated scores
print('CV Mean Score:', cv_mean_score)
# evaluate on the test set
print("Test Score:", test_score)
# Out:
# Best alpha: 187.3817422860383
# Training score: 0.459969947632639
# CV Scores: [0.46068457 0.44819545 0.46761967 0.45615255 0.45796615]
# CV Mean Score: 0.4581238986101712
# Test Score: 0.4658102215420592

# %%
# adding scores to dataframe

r2_scores_df.loc['Ridge'] = [training_score, test_score, cv_mean_score]

# %% [markdown]
# ### Lasso

# %%
model = LassoCV(alphas=np.logspace(-5, 5, 100),cv=5)

pipe = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('model', model)])

pipe.fit(X_train,y_train_log)

best_alpha = model.alpha_
training_score = pipe.score(X_train, y_train_log)
test_score = pipe.score(X_test, y_test_log)

model_l = Lasso(alpha=best_alpha)

pipe_l = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('model', model_l)])

pipe_l.fit(X_train, y_train_log)

cv_scores = cross_val_score(pipe_l, X_train, y_train_log, cv=5)
cv_mean_score = cv_scores.mean()

# get the best alpha
print('Best alpha:', best_alpha)
# evaluate on the training set
print('Training score:', training_score)
# cross-validated scores
print('CV Scores:', cv_scores)
# mean cross-validated scores
print('CV Mean Score:', cv_mean_score)
# evaluate on the test set
print("Test Score:", test_score)
# Out:
# Best alpha: 0.00025950242113997375
# Training score: 0.4599487010765053
# CV Scores: [0.46071373 0.44828263 0.46759563 0.45619771 0.45791069]
# CV Mean Score: 0.4581400776544947
# Test Score: 0.46578279850321136

# %%
# adding scores to dataframe

r2_scores_df.loc['Lasso'] = [training_score, test_score, cv_mean_score]

# %% [markdown]
# ### Elastic Net

# %%
model= ElasticNetCV(l1_ratio=[0.00001, 0.001, 0.01, 0.1, 
                               0.5, 0.7, 0.9, 0.95, 0.99, 1],
                     alphas=np.logspace(-5, 5, 100),
                     cv=5, max_iter=100000)

pipe = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('model', model)])

pipe.fit(X_train,y_train_log)

best_alpha = model.alpha_
best_l1_ratio = model.l1_ratio_
training_score = pipe.score(X_train, y_train_log)
test_score = pipe.score(X_test, y_test_log)

model_en = ElasticNet(alpha=best_alpha, l1_ratio=best_l1_ratio, max_iter=100000)

pipe_en = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('model', model_en)])

pipe_en.fit(X_train, y_train_log)

cv_scores = cross_val_score(pipe_en, X_train, y_train_log, cv=5)
cv_mean_score = cv_scores.mean()

# get the best alpha
print('Best alpha:', best_alpha)
# get the best l1-ratio
print('Best l1-ratio:', best_l1_ratio)
# evaluate on the training set
print('Training score:', training_score)
# cross-validated scores
print('CV Scores:', cv_scores)
# mean cross-validated scores
print('CV Mean Score:', cv_mean_score)
# evaluate on the test set
print("Test Score:", test_score)
# Out:
# Best alpha: 0.00032745491628777284
# Best l1-ratio: 0.9
# Training score: 0.45994331502700314
# CV Scores: [0.46071587 0.44828698 0.46759315 0.45619671 0.45790941]
# CV Mean Score: 0.45814042439302644
# Test Score: 0.465775387258752

# %%
# adding scores to dataframe

r2_scores_df.loc['Elastic Net'] = [training_score, test_score, cv_mean_score]

# %%
# saving a copy of the model scores_dataframe

# joblib.dump(r2_scores_df, 'data/jlib_files/dataframes/r2_scores_df')
# Out:
# ['../data/jlib_files/dataframes/r2_scores_df']

# %% [markdown]
# ### Model Comparison

# %%
fig,ax = plt.subplots(2,1,figsize=(18,10))

r2_scores_df.plot.barh(ax=ax[0],color=['r','g','b'])
ax[0].set_xlim([0.45,0.47])
ax[0].set_title('Score Comparison', fontsize=18)

ax[1].barh(y=r2_scores_df.index,width=r2_scores_df.CV_Mean_Score, height=0.4)
ax[1].set_xlim([0.4581,0.458150])
ax[1].set_title('CV Mean Scores', fontsize=18)

plt.show()

# %% [markdown]
# The elastic net regularisation model is the best performing model with a cross-validated mean score of 0.45814, although it only performs marginally better than the lasso model. Interestingly, all models, performed much better with the unseen data in the test set.

# %% [markdown]
# ### Comparing True Values with Predicted Values

# %%
predictions_train_en = pipe_en.predict(X_train)
predictions_test_en = pipe_en.predict(X_test)

# %%
# instantiating the predicted values

fig, ax = plt.subplots(1,2,figsize=(18,9))


sns.scatterplot(x = y_train, y = np.exp(predictions_train_en), ax=ax[0])
ax[0].set_title('Training Set', fontsize=14)

sns.scatterplot(x = y_test, y = np.exp(predictions_test_en), ax=ax[1],legend=False)
ax[1].set_title('Test Set', fontsize=14)

ax[0].grid()
ax[0].set_xlabel('True Price Value', fontsize=12)
ax[0].set_ylabel('Predicted Price Value', fontsize=12)

ax[1].grid()
ax[1].set_xlabel('True Price Value', fontsize=12)
ax[1].set_ylabel('Predicted Price Value', fontsize=12)


ax[0].plot([0, 1000], [0, 1000], lw=1.5, c='r')
ax[1].plot([0, 1000], [0, 1000], lw=1.5, c='r')

plt.suptitle('Comparison Between True Values and Predictions for Y', fontsize=16, y=0.95)
plt.show()

# %% [markdown]
# Note: I'll be doing a slightly more in-depth analysis of true values vs. predicted values later on this notebook, so won't be discussing these plots in detail.
#
# Interestingly, the model has massively over-predicted the prices for a two properties in the training set. This is most likely because of the artifical cap that was imposed for properties over £1000. Although, as I suspect, a lot of the properties were priced incorrectly, there will be some "luxury" properties that genuinely cost that much. It could be that the model has seen some of the features that would warrant such a high price in these outliers.
#
# Let's set a limit on the y axis so we can get a better idea of the fit of the models.

# %%
# instantiating the predicted values

fig, ax = plt.subplots(1,2,figsize=(18,9))


sns.scatterplot(x = y_train, y = np.exp(predictions_train_en), ax=ax[0])
ax[0].set_title('Training Set', fontsize=14)

sns.scatterplot(x = y_test, y = np.exp(predictions_test_en), ax=ax[1],legend=False)
ax[1].set_title('Test Set', fontsize=14)

ax[0].grid()
ax[0].set_xlabel('True Price Value', fontsize=12)
ax[0].set_ylabel('Predicted Price Value', fontsize=12)

ax[1].grid()
ax[1].set_xlabel('True Price Value', fontsize=12)
ax[1].set_ylabel('Predicted Price Value', fontsize=12)


ax[0].plot([0, 1000], [0, 1000], lw=1.5, c='r')
ax[1].plot([0, 1000], [0, 1000], lw=1.5, c='r')

ax[0].set_ylim(0,1300)

plt.suptitle('Comparison Between True Values and Predictions for Y', fontsize=16, y=0.95)
plt.show()

# %% [markdown]
# We can now see clearly that the fit isn't great. Rather than a line of dots following the diagonal red line, there is a more of a cloud of dots. The main impression I'm gathering is that the model tends to under-predict for higher priced properties. This is evident from the amount of dots under the red line as the true price rises on the x-axis.

# %% [markdown]
# ### Coefficient importance

# %%
# storing the model coefficients in a dataframe
df_coef = pd.DataFrame(model.coef_, index=pipe.named_steps['col_trans'].get_feature_names(),
                       columns=['coefficients'])
# calculate the absolute values of the coefficients
df_coef['coef_abs'] = df_coef.coefficients.abs()

# %%
# plot the magnitude of the coefficients

fig,ax = plt.subplots(figsize=(10,12))

df_coef.sort_values('coef_abs')[-30:].sort_values('coefficients')['coefficients'].plot.barh(ax=ax,
                                                                                            fontsize=13, grid=False)

ax.set_title('Coefficient size for Linear Regression with Elastic Net', fontsize=16)
# ax.set_

plt.show()

# %% [markdown]
# The plot above shows the 30 variables that have the largest magnitude coefficients in the linear regression with elastic net regularisation model.
#
# An aspect that concerns me slightly is that the model thinks that properties in Hillingdon and Havering have a positive impact on the price of a property. My initial thought would have been that they would largely not contain many expensive properties.
#
# Looking at the aggregated tables below, we can confirm that these neighbourhoods do have prices that are well below the median.
#
# Given that both neighbourhoods have a very small number of properties, it could be that the training set happened to contain an inordinate amount of expensive properties from either neighbourhood. In retrospect, it might have made more sense to group the neighbourhoods with small numbers of properties in to an umbrella category.

# %%
df.groupby('neighbourhood').describe().loc[['Havering', 'Hillingdon'],'price']
# Out:
#                count       mean        std   min   25%   50%   75%     max
# neighbourhood
# Havering       249.0  77.068273  95.749165  20.0  30.0  50.0  99.0  1000.0
# Hillingdon     647.0  66.321484  74.254907  20.0  30.5  46.0  80.0  1000.0

# %%
df.describe()[['price']].T
# Out:
#          count        mean         std   min   25%   50%    75%     max
# price  73363.0  105.940638  126.990735  20.0  39.0  70.0  122.0  1000.0

# %% [markdown]
# It's interesting that the model picked out the amount of Airbnb properties a host has as being a strong predictor. If we look at the plot below, we can see that the price of an Airbnb property is generally more expensive the more properties a host owns.
#
# A host owning more properties perhaps suggests that hosting Airbnb properties is their main source of income, rather than someone trying to let a spare room or second house on the side. As such it's to be expected that they might try to maximise their income by leasing a more expensive property.

# %%
df_vis['host_listings_obj'] = df_vis.calculated_host_listings_count.apply(lambda x: "10+" if x>= 10 else x)

fig,ax=plt.subplots(figsize=(18,5))

df_vis.groupby('host_listings_obj').median()['price'].plot.bar(ax=ax, grid=True)

ax.set_title('Median Prices of Properties by Number of Hosts Listings', fontsize=14)
ax.set_xlabel('Number of Hosts Listings', fontsize=12)
ax.set_ylabel('Median Property Price', fontsize=12)

plt.show()

# %% [markdown]
# ### Decision Tree Regressor
#
# The next model I'm going to try is a decision tree regressor. Decision trees work in a completely different way to linear regression models. Rather than creating an algorithm to form a line of best fit for the target variable, decision trees ask a series of questions based on the predictor variables to evaluate what the target variable should be for each observation. Decision trees are better at dealing with outliers than linear regression, which could be an advantage for this project given that the there are lots of outliers in the target variable.

# %%
# using the same pipeline set-up as previously

decision_tree = DecisionTreeRegressor(random_state=1)

pipe = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('decision_tree', decision_tree)])

# %% [markdown]
# In order to achieve the best result possible with the decision tree, I'm going to conduct a grid search to find the highest scoring hyper-parameters for my model.

# %%
params = {'decision_tree__max_depth': range(5,12),
         'decision_tree__min_samples_split': [2,10,20,30,40],
         'decision_tree__min_samples_leaf': [1,5,10,15],
         'decision_tree__max_features': ['auto', 0.8],
         'decision_tree__ccp_alpha': [0, 0.005, 0.01]}

# %%
gs_decision_tree = GridSearchCV(pipe, params, cv=5, n_jobs=-2, verbose=2)

# %%
gs_decision_tree.fit(X_train,y_train)

print("Training Score: {}".format(gs_decision_tree.score(X_train,y_train)))
print("Test Score: {}".format(gs_decision_tree.score(X_test,y_test)))
print("CV Mean Score: {}".format(gs_decision_tree.best_score_))
print("Best Model Parameters: {}".format(gs_decision_tree.best_params_))
# Out:
# Fitting 5 folds for each of 840 candidates, totalling 4200 fits
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  27 tasks      | elapsed:    3.7s
# /Users/jamesradford/opt/anaconda3/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:688: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=-2)]: Done 148 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-2)]: Done 351 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-2)]: Done 634 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-2)]: Done 999 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-2)]: Done 1444 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-2)]: Done 1971 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-2)]: Done 2578 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-2)]: Done 3267 tasks      | elapsed:  7.1min
# ...

# %%
# saving the best-performing decision tree model

# joblib.dump(gs_decision_tree.best_estimator_, 'data/jlib_files/models/model_decision_tree_1')
# Out:
# ['../data/jlib_files/models/model_decision_tree_1']

# %%
# loading the best-performing decision tree model

# decision_tree_1 = joblib.load('data/jlib_files/models/model_decision_tree_1')
# Out:
# ['../data/jlib_files/models/model_decision_tree_1']

# %%
# adding scores to dataframe

r2_scores_df.loc['Decision Tree'] = [gs_decision_tree.score(X_train,y_train), 
                                     gs_decision_tree.score(X_test,y_test),
                                     gs_decision_tree.best_score_]

# %%
# saving a copy of the model scores_dataframe

# joblib.dump(r2_scores_df, 'data/jlib_files/dataframes/r2_scores_df')
# Out:
# ['../data/jlib_files/dataframes/r2_scores_df']

# %%
fig,ax = plt.subplots(figsize=(18,5))

r2_scores_df.plot.barh(ax=ax,color=['r','g','b'])
ax.set_title('Score Comparison', fontsize=18)

plt.show()

# %% [markdown]
# Interestingly, the r2 scores are quite a big improvement on the linear regression with regularisation models! There is a slight drop in the test score, but not enough to suggest that there is an issue with the model's peformance on unseen data. Let's have a look at the formation of the tree and which decisions it's making to begin with.

# %%
# re-fitting the best performing decision tree model for the purpose of visualising the decision tree

decision_tree_best = decision_tree_1.named_steps['decision_tree']

pipe = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('decision_tree_best', decision_tree_best)])

pipe.fit(X_train,y_train)

# %%
tree = export_graphviz(pipe.named_steps['decision_tree_best'],
                           max_depth = 2,
                           filled=True,
                           rounded=True,
                           special_characters=True,
                           feature_names=pipe.named_steps['col_trans'].get_feature_names())

graph = graphviz.Source(tree) 
graph

# %% [markdown]
# The plot above shows the first three series of questions that the tree is asking the dataset. Please note that it is working with standardised data, so the values next to the predictor variables might not be easily interpretable.
#
# Like in the linear regression model, it seems that the decision tree places a lot of importance in how many bathrooms a property has and how many listings a host has.

# %%
feature_names = pipe.named_steps['col_trans'].get_feature_names()
feature_importances = pipe.named_steps['decision_tree_best'].feature_importances_

feature_df = pd.DataFrame({'feature_importance': feature_importances},index=feature_names)

# %%
fig,ax = plt.subplots(figsize=(18,25))

feature_df.sort_values('feature_importance').plot.barh(ax=ax,fontsize=14, legend=False)

ax.set_title('Feature Importance Plot', fontsize=(14))
ax.set_xlabel('Feature Importance', fontsize=(14))

plt.show()

# %% [markdown]
# If we look at the feature importances table, we can see that the model actually only uses a small amount of predictor variables to predict the price. The top predictors are similar to the ones used by the linear regression model, but in a slightly different order. It's interesting that the decision tree values the bathrooms and host_listings_count much more than any other predictor variables.

# %% [markdown]
# ### Comparing True Values with Predicted Values

# %%
predictions_train_dt = pipe.predict(X_train)
predictions_test_dt = pipe.predict(X_test)

# %%
# instantiating the predicted values

fig, ax = plt.subplots(1,2,figsize=(18,9), sharey=True)


sns.scatterplot(x = y_train, y = predictions_train_dt, ax=ax[0])
ax[0].set_title('Training Set', fontsize=14)

sns.scatterplot(x = y_test, y = predictions_test_dt, ax=ax[1],legend=False)
ax[1].set_title('Test Set', fontsize=14)

ax[0].grid()
ax[0].set_xlabel('True Price Value', fontsize=12)
ax[0].set_ylabel('Predicted Price Value', fontsize=12)

ax[1].grid()
ax[1].set_xlabel('True Price Value', fontsize=12)


ax[0].plot([0, 1000], [0, 1000], lw=1.5, c='r')
ax[1].plot([0, 1000], [0, 1000], lw=1.5, c='r')

plt.suptitle('Comparison Between True Values and Predictions for Y', fontsize=16, y=0.95)
plt.show()

# %% [markdown]
# Like previously, we still have the issue of the model being unable to predict the advertised prices of the properties at the low and high ends of the target variable. This is evident from the vertical lines on either sides of the scatterplots.
#
# The decision tree does seem to have more luck with predicting the prices of expensive properties though. If we look at the test set, we can see that although the predictions still aren't accurate, the model seems to understand that there are expensive properties in the dataset. Whereas the linear regression model tended to under-predict the prices, the decision tree has predictions on both sides of the red line, indicating that it is both under- and over-predicting.
#
# Despite these positive signs, the shape of the predictions is still much more cloudy than we would like. Next, we'll be trying some ensemble models, which are much more powerful, and computationally expensive, than either linear regression or decision trees.
#
# The three models I'm going to run are Random Forest, Gradient Boosting and Bagging Regressors.

# %% [markdown]
# ### Random Forest Regressor

# %%
random_forest = RandomForestRegressor(n_jobs=-2,random_state=1, verbose=1)

pipe = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('random_forest', random_forest)])

params = {'random_forest__n_estimators': [100, 150],
         'random_forest__max_depth': [None, 10, 50],
         'random_forest__min_samples_leaf': [1,5,30],
         'random_forest__max_features': ['auto', 0.8],
         'random_forest__max_samples': [None, 0.8],
         'random_forest__ccp_alpha': [0, 0.005, 0.01]}

gs_random_forest = GridSearchCV(pipe, params, cv=5, n_jobs=-2, verbose=2)

# %%
gs_random_forest.fit(X_train,y_train)

print("Training Score: {}".format(gs_random_forest.score(X_train,y_train)))
print("Test Score: {}".format(gs_random_forest.score(X_test,y_test)))
print("CV Mean Score: {}".format(gs_random_forest.best_score_))
print("Best Model Parameters: {}".format(gs_random_forest.best_params_))
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  27 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-2)]: Done 148 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-2)]: Done 351 tasks      | elapsed: 44.5min
# [Parallel(n_jobs=-2)]: Done 634 tasks      | elapsed: 105.2min
# [Parallel(n_jobs=-2)]: Done 999 tasks      | elapsed: 191.9min
# [Parallel(n_jobs=-2)]: Done 1080 out of 1080 | elapsed: 213.4min finished
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-2)]: Done 150 out of 150 | elapsed:  1.5min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.1s
# Training Score: 0.9459556960470796
# Test Score: 0.6291665344653148
# ...

# %%
# saving the pipeline and best estimator

# joblib.dump(pipe,'data/jlib_files/pipe_random_forest_1')
# joblib.dump(gs_random_forest.best_estimator_,'data/jlib_files/model_random_forest_1')
# Out:
# ['../data/jlib_files/model_random_forest_1']

# %%
training_score = gs_random_forest.score(X_train,y_train)
test_score = gs_random_forest.score(X_test, y_test)
cv_mean_score = gs_random_forest.best_score_

# %%
r2_scores_df.loc['Random Forest'] = [training_score, test_score, cv_mean_score]

# %%
# saving a copy of the model scores_dataframe

# joblib.dump(r2_scores_df, 'data/jlib_files/dataframes/r2_scores_df')
# Out:
# ['../data/jlib_files/dataframes/r2_scores_df']

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
gradient_boosting = GradientBoostingRegressor(random_state=1)

pipe = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('gradient_boosting', gradient_boosting)])

params = {'gradient_boosting__n_estimators': [100,150],
         'gradient_boosting__subsample': [0.8, 1],
         'gradient_boosting__min_samples_split': [2,15,30],
         'gradient_boosting__min_samples_leaf': [1, 5],
         'gradient_boosting__max_depth': [3, 5, 10],
         'gradient_boosting__max_features': ['auto', 'sqrt'],
         'gradient_boosting__ccp_alpha': [0, 0.005, 0.01]
         }

gs_grad_boost = GridSearchCV(pipe, params, cv=5, n_jobs=-2, verbose=1)

# %%
gs_grad_boost.fit(X_train,y_train)

print("Training Score: {}".format(gs_grad_boost.score(X_train,y_train)))
print("Test Score: {}".format(gs_grad_boost.score(X_test,y_test)))
print("CV Mean Score: {}".format(gs_grad_boost.best_score_))
print("Best Model Parameters: {}".format(gs_grad_boost.best_params_))
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# /Users/jamesradford/opt/anaconda3/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:688: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-2)]: Done 436 tasks      | elapsed: 29.6min
# [Parallel(n_jobs=-2)]: Done 786 tasks      | elapsed: 68.0min
# [Parallel(n_jobs=-2)]: Done 1236 tasks      | elapsed: 101.4min
# [Parallel(n_jobs=-2)]: Done 1786 tasks      | elapsed: 149.3min
# [Parallel(n_jobs=-2)]: Done 2160 out of 2160 | elapsed: 184.6min finished
# Training Score: 0.893968414648733
# Test Score: 0.6262948839118985
# CV Mean Score: 0.6134737528844415
# ...

# %%
# saving the pipeline and best estimator

# joblib.dump(pipe,'data/jlib_files/pipe_gradient_boosting_1')
# joblib.dump(gs_grad_boost.best_estimator_,'data/jlib_files/model_gradient_boosting_1')
# Out:
# ['../data/jlib_files/model_gradient_boosting_1']

# %%
training_score = gs_grad_boost.score(X_train,y_train)
test_score = gs_grad_boost.score(X_test, y_test)
cv_mean_score = gs_grad_boost.best_score_

# %%
# saving a copy of the model scores_dataframe

# joblib.dump(r2_scores_df, 'data/jlib_files/dataframes/r2_scores_df')
# Out:
# ['../data/jlib_files/dataframes/r2_scores_df']

# %% [markdown]
# ### Bagging Regressor

# %%
decision_tree = DecisionTreeRegressor(random_state=1)

bagging_regressor = BaggingRegressor(base_estimator=decision_tree, n_jobs=-2, random_state=1)

pipe = Pipeline(steps = [('col_trans', col_trans),
                        ('scaler', scaler),
                        ('br', bagging_regressor)])

params = {'br__n_estimators': [20, 60, 120],
         'br__max_samples': [0.5, 0.8, 1.0, 1.2],
         'br__max_features': [0.5, 0.8, 1.0, 1.2],
         'br__bootstrap': [True, False]}

gs_bag_regressor = GridSearchCV(pipe, params, cv=5, n_jobs=-2, verbose=1)

# %%
gs_bag_regressor.fit(X_train,y_train)

print("Training Score: {}".format(gs_bag_regressor.score(X_train,y_train)))
print("Test Score: {}".format(gs_bag_regressor.score(X_test,y_test)))
print("CV Mean Score: {}".format(gs_bag_regressor.best_score_))
print("Best Model Parameters: {}".format(gs_bag_regressor.best_params_))
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# /Users/jamesradford/opt/anaconda3/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:688: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-2)]: Done 186 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-2)]: Done 436 tasks      | elapsed: 29.2min
# [Parallel(n_jobs=-2)]: Done 480 out of 480 | elapsed: 29.3min finished
# Training Score: 0.9992404641224039
# Test Score: 0.636997049016767
# CV Mean Score: 0.6187037094125625
# Best Model Parameters: {'br__bootstrap': False, 'br__max_features': 0.5, 'br__max_samples': 1.0, 'br__n_estimators': 120}

# %%
# saving a copy of the model scores_dataframe

# joblib.dump(gs_bag_regressor.best_estimator_, 'data/jlib_files/models/model_bagging_regressor_1')
# Out:
# ['../data/jlib_files/models/model_bagging_regressor_1']

# %%
training_score = gs_bag_regressor.score(X_train,y_train)
test_score = gs_bag_regressor.score(X_test, y_test)
cv_mean_score = gs_bag_regressor.best_score_

# %%
r2_scores_df.loc['Bagging Regressor'] = [training_score, test_score, cv_mean_score]

# %%
# saving a copy of the model scores_dataframe

# joblib.dump(r2_scores_df, 'data/jlib_files/dataframes/r2_scores_df')
# Out:
# ['../data/jlib_files/dataframes/r2_scores_df']

# %% [markdown]
# ## Compare scores of all models

# %%
fig,ax = plt.subplots(figsize=(18,10))

r2_scores_df.plot.barh(ax=ax,color=['r','g','b'], fontsize=14)
ax.set_title('Score Comparison', fontsize=18)

plt.show()

# %% [markdown]
# # Bagging regressor analysis

# %%
bag_reg = joblib.load("data/jlib_files/models/model_bagging_regressor_1")
bag_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('col_trans',
#                  ColumnTransformer(remainder='passthrough', sparse_threshold=0,
#                                    transformers=[('dummy',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['host_response_time',
#                                                    'host_response_rate',
#                                                    'host_acceptance_rate',
#                                                    'neighbourhood', 'room_type',
#                                                    'property_type_basic'])])),
#                 ('scaler', StandardScaler()),
#                 ('br',
#                  BaggingRegressor(base_estimator=DecisionTreeRegressor(random_state=1),
#                                   bootstrap=False, max_features=0.5,
# ...

# %%
# combining train and test sets and adding the predictions

predictions_train = bag_reg.predict(X_train)
predictions_test = bag_reg.predict(X_test)

train_vis = X_train.copy()
test_vis = X_test.copy()

train_vis['price_true'] = y_train
test_vis['price_true'] = y_test

train_vis['price_pred'] = predictions_train
test_vis['price_pred'] = predictions_test

train_vis['residuals'] = train_vis.price_true - train_vis.price_pred
test_vis['residuals'] = test_vis.price_true - test_vis.price_pred

train_vis['residuals_abs'] = abs(train_vis.residuals)
test_vis['residuals_abs'] = abs(test_vis.residuals)

# %%
fig, ax = plt.subplots(3,2,figsize=(18,24), sharey=True)

for ax_tuple, variable in zip(enumerate(ax.flatten()),[None, None, 'room_type','room_type', 'accommodates', 'accommodates']):
    
    if ax_tuple[0]%2==0:
        sns.scatterplot(x = 'price_true', y = 'price_pred', hue = variable, data = train_vis, ax=ax_tuple[1])
        ax_tuple[1].set_title('Training Set', fontsize=14)
    else:    
        sns.scatterplot(x = 'price_true', y = 'price_pred', hue = variable, data = test_vis, ax=ax_tuple[1],
                       legend=False)
        ax_tuple[1].set_title('Test Set', fontsize=14)

    ax_tuple[1].grid()
    ax_tuple[1].set_xlabel('True Price Value', fontsize=12)
    ax_tuple[1].set_ylabel('Predicted Price Value', fontsize=12)

    ax_tuple[1].plot([0, df.price.max()], [0, df.price.max()], lw=1.5, c='r')

plt.suptitle('Comparison Between True Values and Predictions for Y', fontsize=16, y=0.92)
plt.show()

# %% [markdown]
# The scatterplots of the training set are not much use to use for the bagging regressor, as the model is set up to the over-fit on the training data. Instead, we should focus purely on the test set scatterplots.
#
# The shape of the dots is still slightly cloudy, but does seem to have a marginally better fit than previous models. Like previously, the model seems to under-predict the prices of expensive properties. This is evident from the amount of predictions in the middle to upper right-hand side of the plot beneath the red line.
#
# Another issue, as seen in the plot on the second row, is that there are quite a lot of expensive private rooms that the model has under-predicted the price of. Given that private rooms are normally much cheaper than entire properties, I'm suspect that these might be mislabelled properties. It surely can't be common to pay above average price for an Airbnb property just to stay in someone's room?
#
# Also, we can see that there are unnatural lines of dots on either side of both plots. These represent the artificial lower and upper limits that I placed on extremely low and high prices. What's interesting is that there are huge residual values for properties sitting on both of these limits.
#
# This is an inherent issue with the dataset in that it contains advertised property prices rather than the prices that guests have paid. My assumption is that hosts have either listed these extremely low/high prices by mistake or, in the case of the latter, to stop people from renting their property.

# %% [markdown]
# ## Feature importances in the gradient boosting regressor
#
# Since that we can't view the feature importances for a bagging regressor, it would be interesting to see the order of how our second best-performing ensemble model, the gradient boosting regressor, valued the predictor variables.

# %%
# loading the gradient boosting model

grad_boost = joblib.load('data/jlib_files/models/model_gradient_boosting_1')

grad_boost.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('col_trans',
#                  ColumnTransformer(remainder='passthrough', sparse_threshold=0,
#                                    transformers=[('dummy',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['host_response_time',
#                                                    'host_response_rate',
#                                                    'host_acceptance_rate',
#                                                    'neighbourhood', 'room_type',
#                                                    'property_type_basic'])])),
#                 ('scaler', StandardScaler()),
#                 ('gradient_boosting',
#                  GradientBoostingRegressor(ccp_alpha=0, max_depth=10,
#                                            max_features='sqrt',
# ...

# %%
feature_names = grad_boost.named_steps['col_trans'].get_feature_names()
feature_importances = grad_boost.named_steps['gradient_boosting'].feature_importances_

feature_df = pd.DataFrame({'feature_importance': feature_importances},index=feature_names)

# %%
fig,ax = plt.subplots(figsize=(18,25))

feature_df.sort_values('feature_importance').plot.barh(ax=ax,fontsize=14, legend=False)

ax.set_title('Feature Importance Plot', fontsize=(14))
ax.set_xlabel('Feature Importance', fontsize=(14))

plt.show()

# %% [markdown]
# There are no real suprises in the feature importance plot above, apart from perhaps how high the text length variables (name, host about, description and neighbourhood overview) are on the list. On this topic, it's interesting that the host about variable is deemed much more important than the other text length variables. This fact in combination with the host listings count suggests that host attributes could be an important factor in determining price.

# %% [markdown]
# ## Summary
#
# - it is encouraging that we've been able to increase the cv mean score from 0.4581 to 0.6187, but the model is still not a very trustworthy predictor
# - as shown in the predicted vs true values scatterplots, there are too many instances where the predicted value is a long way off the true value
# - the model tends to under-predict prices, especially at the upper-end of the price range
# - the predictors that we're working with are limited - I suspect that a lot of the information that determines price lies in the property photographs: the view from the bedrooms window, the quality/stylishness of the furniture etc.
# - we are also slightly hindered by the dataset, it would be much better if we could work with prices paid for properties rather than the advertised prices
# - as previously mentioned, the advertised prices contain a lot of anomalies

# %% [markdown]
# ## What we can do next
#
# - include natural language processing for the text variables - they might be able to help the model work out whether a property is expensive or not
# - simplify the project by attempting a classification model to predict price categories rather than actual prices
# - use neural network models to predict prices
# - acquire better Airbnb data, either by paying for it or scraping it directly from their website
